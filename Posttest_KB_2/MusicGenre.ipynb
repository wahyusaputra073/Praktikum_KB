# %% [markdown]
# ### POSTTEST 2 - KECERDASAN BUATAN
# ### Nama   : Wahyu Harry Saputra Sembiring
# ### NIM      : 2009106049
# ### Kelas   : Informatika A 2020

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate
df = pd.read_csv("music_genre.csv")
df = df.iloc[:3000]

# %% [markdown]
# ### Informasi yang didapatkan adalah jumlah record, nama attribute, jumlah attribute dengan tipe objek, jumlah attribute dengan tipe angka, jumlah attribute yang memiliki nilai null.

# %%
# Jumlah record
jumlah = len(df)
print(Jumlah)

# nama atribut
nama = list(df.columns)
print(nama)

# jumlah atribut tipe objek
jumlah_objek = len(df.dtypes[df.dtypes == 'object'])
print(jumlah_objek)

# jumlah atribut tipe angka
jumlah_integer =len(df.dtypes[df.dtypes == 'int64'])
jumlah_float =len(df.dtypes[df.dtypes == 'float64'])
jumlah_angka = jumlah_integer + jumlah_float
print(jumlah_angka)

#jumlah atribut nilai null
df.isna().any().sum()
# Out:
# 3000
# ['instance_id', 'artist_name', 'track_name', 'popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'obtained_date', 'valence', 'music_genre']
# 7
# 11
# 0

# %% [markdown]
# ### Masukkan informasi di atas dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

# %%
## Masukkan informasi di atas dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

#Jumlah record
jumlah = len(df)

#Nama Atribut
nama = list(df.columns)
nama = ",\n".join(nama)

# jumlah atribut tipe objek
jumlah_objek = len(df.dtypes[df.dtypes == 'object'])


# jumlah atribut tipe angka
jumlah_angka = len(df.dtypes[df.dtypes == 'int64'])

# jumlah atribut nilai null
jumlah_null = df.isna().any().sum()


kamus = {
    "Jumlah Record":[Jumlah],
    "Nama Atribut" : [nama],
    "Jumlah atribut tipe objek" : [jumlah_objek],
    "Jumlah atribut tipe angka" : [jumlah_angka],
    "Jumlah atribut nilai null"  : [jumlah_null],
    
}

tab = pd.DataFrame(kamus)
print(tabulate(tab, headers='keys', tablefmt='psql',showindex=False))
# Out:
# +-----------------+-------------------+-----------------------------+-----------------------------+-----------------------------+
# |   Jumlah Record | Nama Atribut      |   Jumlah atribut tipe objek |   Jumlah atribut tipe angka |   Jumlah atribut nilai null |
# |-----------------+-------------------+-----------------------------+-----------------------------+-----------------------------|
# |            3000 | instance_id,      |                           7 |                           1 |                           0 |
# |                 | artist_name,      |                             |                             |                             |
# |                 | track_name,       |                             |                             |                             |
# |                 | popularity,       |                             |                             |                             |
# |                 | acousticness,     |                             |                             |                             |
# |                 | danceability,     |                             |                             |                             |
# |                 | duration_ms,      |                             |                             |                             |
# |                 | energy,           |                             |                             |                             |
# |                 | instrumentalness, |                             |                             |                             |
# |                 | key,              |                             |                             |                             |
# |                 | liveness,         |                             |                             |                             |
# |                 | loudness,         |                             |                             |                             |
# |                 | mode,             |                             |                             |                             |
# |                 | speechiness,      |                             |                             |                             |
# |                 | tempo,            |                             |                             |                             |
# |                 | obtained_date,    |                             |                             |                             |
# |                 | valence,          |                             |                             |                             |
# |                 | music_genre,      |                             |                             |                             |
# |                 | high              |                             |                             |                             |
# +-----------------+-------------------+-----------------------------+-----------------------------+-----------------------------+

# %% [markdown]
# ### Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
df.describe()
# Out:
#         instance_id   popularity  acousticness  danceability   duration_ms  \
# count   3000.000000  3000.000000   3000.000000   3000.000000  3.000000e+03
# mean   55889.304000    38.213667      0.125203      0.618617  2.439571e+05
# std    20692.016523     9.786859      0.205298      0.147144  1.659117e+05
# min    20005.000000     0.000000      0.000002      0.082200 -1.000000e+00
# 25%    37881.750000    31.000000      0.004128      0.528000  1.932440e+05
# 50%    55776.000000    37.000000      0.026800      0.629000  2.375460e+05
# 75%    73555.000000    44.000000      0.144250      0.723000  2.999775e+05
# max    91744.000000    96.000000      0.985000      0.968000  4.830606e+06
#
#             energy  instrumentalness     liveness     loudness  speechiness  \
# count  3000.000000       3000.000000  3000.000000  3000.000000  3000.000000
# mean      0.739419          0.338432     0.209612    -6.996947     0.100069
# std       0.188446          0.362087     0.175044     3.713095     0.100109
# min       0.021100          0.000000     0.017300   -24.798000     0.023400
# 25%       0.612000          0.002577     0.095800    -9.254500     0.040400
# 50%       0.775500          0.143000     0.129000    -6.381500     0.057800
# 75%       0.900250          0.742250     0.282250    -4.318500     0.112000
# max       0.998000          0.986000     0.959000     0.892000     0.774000
#
#            valence
# count  3000.000000
# mean      0.388991
# std       0.236917
# min       0.029500
# 25%       0.193000
# 50%       0.358500
# 75%       0.556000
# max       0.984000

# %% [markdown]
# ### Tampilkan nilai korelasi attribute bertipe angka.

# %%
df.corr()
# Out:
#                   instance_id  popularity  acousticness  danceability  \
# instance_id          1.000000   -0.019051      0.016242     -0.010527
# popularity          -0.019051    1.000000      0.031603      0.059180
# acousticness         0.016242    0.031603      1.000000     -0.086466
# danceability        -0.010527    0.059180     -0.086466      1.000000
# duration_ms         -0.037904    0.020223      0.046570      0.008973
# energy              -0.022010   -0.042754     -0.541810     -0.033335
# instrumentalness     0.023501   -0.085234      0.171597      0.039119
# liveness            -0.006717   -0.040973     -0.101671     -0.111151
# loudness            -0.018472   -0.001518     -0.514332     -0.020062
# speechiness         -0.027058   -0.090833     -0.125212      0.031281
# valence              0.007873    0.034148     -0.058295      0.408413
#
#                   duration_ms    energy  instrumentalness  liveness  loudness  \
# instance_id         -0.037904 -0.022010          0.023501 -0.006717 -0.018472
# popularity           0.020223 -0.042754         -0.085234 -0.040973 -0.001518
# acousticness         0.046570 -0.541810          0.171597 -0.101671 -0.514332
# danceability         0.008973 -0.033335          0.039119 -0.111151 -0.020062
# duration_ms          1.000000 -0.098022          0.163050 -0.040003 -0.169599
# energy              -0.098022  1.000000         -0.194139  0.231328  0.761331
# instrumentalness     0.163050 -0.194139          1.000000 -0.081092 -0.405311
# liveness            -0.040003  0.231328         -0.081092  1.000000  0.184776
# loudness            -0.169599  0.761331         -0.405311  0.184776  1.000000
# speechiness         -0.086273  0.264332         -0.244256  0.171407  0.278606
# valence             -0.029487  0.129390         -0.084629 -0.013938  0.054038
#
#                   speechiness   valence
# instance_id         -0.027058  0.007873
# popularity          -0.090833  0.034148
# acousticness        -0.125212 -0.058295
# danceability         0.031281  0.408413
# duration_ms         -0.086273 -0.029487
# energy               0.264332  0.129390
# instrumentalness    -0.244256 -0.084629
# liveness             0.171407 -0.013938
# loudness             0.278606  0.054038
# speechiness          1.000000 -0.009517
# valence             -0.009517  1.000000

# %% [markdown]
# ### Rubah nilai salah satu attribute bertipe angka menjadi desimal 3 angka dibelakang koma jika tidak ada, lakukan sebaliknya (dari desimal menjadi bilangan bulat).

# %%
df["energy"].dtypes
print(df["energy"].dtypes)

df["high"] = df["energy"].astype("int64")
print(df["energy"].dtypes)
# Out:
# float64
# float64

# %% [markdown]
# ### Tampilkan 10 record pertama dari attribute bertipe angka.

# %%
df_angka= df.select_dtypes(include=['float64','int64'])

df_angka.head(10)
# Out:
#    instance_id  popularity  acousticness  danceability  duration_ms  energy  \
# 0      32894.0        27.0       0.00468         0.652         -1.0   0.941
# 1      46652.0        31.0       0.01270         0.622     218293.0   0.890
# 2      30097.0        28.0       0.00306         0.620     215613.0   0.755
# 3      62177.0        34.0       0.02540         0.774     166875.0   0.700
# 4      24907.0        32.0       0.00465         0.638     222369.0   0.587
# 5      89064.0        47.0       0.00523         0.755     519468.0   0.731
# 6      43760.0        46.0       0.02890         0.572     214408.0   0.803
# 7      30738.0        43.0       0.02970         0.809     416132.0   0.706
# 8      84950.0        39.0       0.00299         0.509     292800.0   0.921
# 9      56950.0        22.0       0.00934         0.578     204800.0   0.731
#
#    instrumentalness  liveness  loudness  speechiness  valence  high
# 0          0.792000    0.1150    -5.201       0.0748    0.759     0
# 1          0.950000    0.1240    -7.043       0.0300    0.531     0
# 2          0.011800    0.5340    -4.617       0.0345    0.333     0
# 3          0.002530    0.1570    -4.498       0.2390    0.270     0
# 4          0.909000    0.1570    -6.266       0.0413    0.323     0
# 5          0.854000    0.2160   -10.517       0.0412    0.614     0
# 6          0.000008    0.1060    -4.294       0.3510    0.230     0
# 7          0.903000    0.0635    -9.339       0.0484    0.761     0
# 8          0.000276    0.1780    -3.175       0.2680    0.273     0
# 9          0.011200    0.1110    -7.091       0.1730    0.203     0

# %% [markdown]
# ### Simpan dataset dengan attribute bertipe angka ke dalam file CSV.

# %%
df_angka.to_csv("AtributAngka_Posttest2.csv", index=False)
