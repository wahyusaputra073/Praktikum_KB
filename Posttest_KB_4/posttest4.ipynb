# %% [markdown]
# ### POSTTEST 4 - DATA-PREPROCESSING
# ### Nama   :   Wahyu Harry Saputra Sembiring
# ### NIM      :    2009106049
# ### Kelas   :    Informatika A 2020

# %%
# Import module yang dibutuhkan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('Car details v3.csv')
df = df.iloc[:1500]

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
# Subset feature dan target
X = df.iloc[:,:-1] # Target
y = df.iloc[:,-1] # Feature

# %% [markdown]
# ### Bagi dataset menjadi training set dan testing set dengan proporsi 70:30

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %%
print("Dimensi X_train: ", X_train.shape)
print("Dimensi X_test: ", X_test.shape)
print("Dimensi y_train: ", y_train.shape)
print("Dimensi y_test: ", y_test.shape)
# Out:
# Dimensi X_train:  (1050, 12)
# Dimensi X_test:  (450, 12)
# Dimensi y_train:  (1050,)
# Dimensi y_test:  (450,)

# %% [markdown]
# #

# %% [markdown]
# ### Lakukan normalisasi data pada salah satu attribute menggunakan Min Max scaler (buatlah copy dataset          terlebih dahulu)

# %%
dfCopy = pd.read_csv('Car details v3.csv')

# %%
mms = MinMaxScaler()

# %%
x_scaled = mms.fit_transform(dfCopy[["selling_price","km_driven","year"]])

# %%
dfCopy.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# #

# %% [markdown]
# #### Normalization metode Z-Score

# %%
dfCopy["selling_price"] = dfCopy["selling_price"] / dfCopy["selling_price"].std()
dfCopy["km_driven"] = dfCopy["km_driven"] / dfCopy["km_driven"].std()

# %%
dfCopy.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014       0.558137   2.572919  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014       0.458913   2.121995  Diesel
# 2      Honda City 2017-2020 EXi  2006       0.195968   2.475661  Petrol
# 3     Hyundai i20 Sportz Diesel  2010       0.279069   2.245778  Diesel
# 4        Maruti Swift VXI BSIII  2007       0.161240   2.121995  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# #

# %% [markdown]
# ### Lakukan standarisasi pada dataset (buatlah copy dataset terlebih dahulu)

# %%
plt.plot(dfCopy.year, dfCopy.selling_price)
plt.show()

# %%
ss = StandardScaler()

# %%
x_skala = ss.fit_transform(dfCopy[["selling_price","year"]])

# %%
data_standardisasi = pd.DataFrame(x_skala)

# %%
plt.plot(dfCopy.year, dfCopy.selling_price)
plt.show()

# %% [markdown]
# ### Lakukan Data cleaning pada data dengan nilai null (jika tidak ada nilai null pada dataset, maka buatlah menjadi ada). Ganti nilai null sesuai ketentuan. (bilangan bulat : median/modus, bilangan desimal : mean, tulisan : modus). Nilai plus jika strategy yang digunakan menggunakan 3 nila

# %%
print("Data sebelum dicleaning")
df.isna().sum()
# Out:
# Data sebelum dicleaning
# name              0
# year              0
# selling_price     0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage          47
# engine           47
# max_power        43
# torque           47
# seats            47
# dtype: int64

# %%
imputer = SimpleImputer(strategy="mean")
imputerString = SimpleImputer(strategy="most_frequent")

# %%
df['seats'] = imputer.fit_transform(df[['seats']])
df['mileage'] = imputerString.fit_transform(df[['mileage']])
df['engine'] = imputerString.fit_transform(df[['engine']])
df['max_power'] = imputerString.fit_transform(df[['max_power']])
df['torque'] = imputerString.fit_transform(df[['torque']])

# %%
print("Data setelah dicleaning")
df.isna().sum()
# Out:
# Data setelah dicleaning
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df[10:150]
# Out:
# Data setelah dicleaning
#                                 name  year  selling_price  km_driven    fuel  \
# 10   Renault Duster 110PS Diesel RxL  2014       0.560338   1.514548  Diesel
# 11                     Maruti Zen LX  2005       0.103102   2.227277  Petrol
# 12            Maruti Swift Dzire VDi  2009       0.313789   3.118188  Diesel
# 13              Maruti Swift 1.3 VXi  2007       0.224135   1.781821  Petrol
# 14          Maruti Wagon R LXI Minor  2009       0.201722   2.004549  Petrol
# ..                               ...   ...            ...        ...     ...
# 145           Volvo XC40 D4 R-Design  2018       3.810301   0.490001  Diesel
# 146   Audi Q7 35 TDI Quattro Premium  2015       2.969793   1.180457  Diesel
# 147                  Maruti Ciaz ZDi  2015       0.599562   0.890911  Diesel
# 148  Mercedes-Benz S-Class S 350 CDI  2017       6.555959   1.046820  Diesel
# 149                BMW 5 Series 523i  2010       1.092660   1.608094  Petrol
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, torque, seats]
# Index: []

# %% [markdown]
# #

# %% [markdown]
# ### Lakukan Data cleaning pada data dengan nilai duplikat. (Jika tidak ada nilai duplikat pada dataset, maka buatlah menjadi ada)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
df[df.duplicated()]
# Out:
#                                           name  year  selling_price  \
# 291                   Hyundai Grand i10 Sportz  2017       0.504305
# 296                           Maruti Swift VXI  2012       0.369823
# 370   Jaguar XE 2016-2019 2.0L Diesel Prestige  2017       2.941777
# 371                              Lexus ES 300h  2019       5.771485
# 372             Jaguar XF 2.0 Diesel Portfolio  2017       3.586166
# ...                                        ...   ...            ...
# 1342              Honda Brio Exclusive Edition  2014       0.375427
# 1343                 Hyundai Grand i10 AT Asta  2015       0.521115
# 1443           Maruti Swift Dzire VDI Optional  2017       0.660079
# 1446           Maruti Vitara Brezza VDi Option  2018       0.862921
# 1455                  Maruti Vitara Brezza VDi  2017       0.874128
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, torque, seats]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# ### Ganti tipe data salah satu attribute angka

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price    float64
# km_driven        float64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
encoder = OrdinalEncoder()
df['yearEncoded'] = encoder.fit_transform(df[['year']])

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014       0.504305   3.240688  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014       0.414650   2.672732  Diesel
# 2      Honda City 2017-2020 EXi  2006       0.177067   3.118188  Petrol
# 3     Hyundai i20 Sportz Diesel  2010       0.252152   2.828642  Diesel
# 4        Maruti Swift VXI BSIII  2007       0.145688   2.672732  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  seatsEncoded  yearEncoded
# ...

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price    float64
# km_driven        float64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# seatsEncoded     float64
# dtype: object

# %% [markdown]
# ### Lakukan one hot encoding pada dataset yang kalian miliki.

# %%
encoderHot = OneHotEncoder(sparse=False)

# %%
yearEnc = encoder.fit_transform(df[['year']])

# %%
yearHotEnc = pd.DataFrame(yearEnc)

# %%
df = df.join(yearHotEnc)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014       0.504305   3.240688  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014       0.414650   2.672732  Diesel
# 2      Honda City 2017-2020 EXi  2006       0.177067   3.118188  Petrol
# 3     Hyundai i20 Sportz Diesel  2010       0.252152   2.828642  Diesel
# 4        Maruti Swift VXI BSIII  2007       0.145688   2.672732  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  seatsEncoded  yearEncoded     0
# ...
